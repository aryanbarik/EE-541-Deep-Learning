# %% [markdown]
# # Homework 1
# ### Aryan Barik
#
# ## 1a

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
flips = []

for i in range(50):
    flips.append(random.random())

print(flips)

total_heads = 0
longest_run_heads = 0
current_run_heads = 0
is_last_flip_heads = False

# dont lose greatest value from streak to streak

for i in flips:
    if i >= 0.30:
        total_heads += 1
        if is_last_flip_heads:
            current_run_heads += 1
        
        else:    
            is_last_flip_heads = True
            current_run_heads = 1

    else:
        is_last_flip_heads = False
        current_run_heads = 0
    
    if current_run_heads > longest_run_heads:
        longest_run_heads = current_run_heads

print("Longest run of heads is:", longest_run_heads)
print("Total number of heads is:", total_heads)
# Out:
# [0.4714851941026852, 0.9464796955157577, 0.09459472382151723, 0.7182678963538633, 0.36696855037938025, 0.3836292330629505, 0.04340114217411983, 0.7481264426907942, 0.8296839741899602, 0.7295604813827845, 0.03297578829485881, 0.8246604245349372, 0.16095325893442824, 0.9409009890711562, 0.09987021521485284, 0.5503746592031243, 0.23510611191174302, 0.9632925711231528, 0.9977632573434452, 0.6525869632794866, 0.029084117378042507, 0.15475745561713194, 0.10410730144002112, 0.15576348574018284, 0.2537049489233578, 0.8008244170850362, 0.9826057079364604, 0.1045358148599016, 0.12273888074102934, 0.9521921245283798, 0.2768037244603856, 0.9472948355489565, 0.7419595683892575, 0.02220771413406608, 0.44473863527837465, 0.48371604629034926, 0.40820261849318806, 0.9753456334988927, 0.15169108332146763, 0.3635873874266484, 0.8909597510764026, 0.6371160584164516, 0.3522412435078467, 0.7036094470569575, 0.03128980690207406, 0.6135534328565997, 0.5823011156128044, 0.6680540827801659, 0.6528061178554464, 0.7947359895009497]
# Longest run of heads is: 5
# Total number of heads is: 33

# %% [markdown]
# ## 1b

# %%
def fifty_flip_experiment():
    flips = []

    for i in range(50):
        flips.append(random.random())

    total_heads = 0

    for i in flips:
        if i >= 0.30:
            total_heads += 1
            
    return total_heads

# %%
def repeat_experiment(x):
    heads = []
    for i in range(x):
        heads.append(fifty_flip_experiment())

    print(heads)

    # histogram
    plt.hist(heads)
    plt.xlabel('Heads')
    plt.ylabel('Frequency')
    plt.title('Heads from 50 Flips Repeated X times')

    plt.show()

# %%
repeat_experiment(20)
# Out:
# [31, 34, 31, 36, 35, 28, 37, 37, 35, 35, 35, 37, 34, 30, 33, 31, 34, 38, 37, 41]

# %%
repeat_experiment(100)
# Out:
# [37, 32, 37, 37, 37, 36, 35, 37, 37, 34, 40, 35, 33, 38, 37, 31, 35, 38, 35, 31, 40, 36, 41, 36, 32, 40, 34, 36, 34, 38, 39, 32, 32, 30, 36, 36, 38, 31, 32, 35, 37, 33, 34, 31, 41, 36, 31, 36, 37, 32, 36, 36, 39, 27, 35, 31, 39, 37, 29, 34, 35, 36, 38, 33, 31, 36, 37, 31, 37, 40, 35, 34, 35, 36, 37, 34, 33, 33, 37, 32, 27, 35, 35, 36, 33, 38, 38, 39, 33, 41, 32, 35, 36, 32, 38, 33, 29, 37, 40, 36]

# %%
repeat_experiment(200)
# Out:
703282996236, 0.6793312670760019, 0.036447095679231656, 0.9770365993840004, 0.8231046030803304, 0.552297826318932, 0.4006881572086961, 0.9861676692380931, 0.48359022003735685, 0.9408597349793673, 0.44837089036289945, 0.5135434119768584, 0.9505408429954657, 0.47286190453418186, 0.8925517159379366, 0.7359938547708272, 0.13529922733732236, 0.8730913024024518, 0.791178706533208, 0.8885799760759283, 0.530910644496166, 0.15011411220866666, 0.005276148570259376, 0.8793085704416281, 0.8968549432188924, 0.5855056030929715, 0.35273632993362336, 0.21635854366773455, 0.7687741887829712, 0.5997016950640192, 0.9199039005287305, 0.33854549123094646, 0.8433594257768068, 0.5109754155425552, 0.6301758244805261, 0.7697546000424211, 0.6435177704618357, 0.9856871834458975, 0.3985666888366888, 0.3405099878214901, 0.549811110487508, 0.37209000430896855, 0.7703349804010423, 0.317472048832927, 0.515458808638161, 0.6204781336041844, 0.17926302152630424, 0.38903677028609374, 0.8212651211847264, 0.605806800291306, 0.7338957894969389, 0.3570820855347032, 0.09594744927531629, 0.12196816092375606, 0.5298351058950377, 0.7526699119371453, 0.4486889589684542, 0.8206254580042751, 0.9635414400123047, 0.26430674811710286, 0.9489224023334046, 0.7341610865323707, 0.7487110045766325, 0.2833790933270429, 0.09557245847825324, 0.48434823373790736, 0.6108507114777746, 0.4363407690634281, 0.8352558646268572, 0.19833600050045253, 0.6125030511037238, 0.27169193125544344, 0.4793268568831902, 0.5581414257679708, 0.8799407533462517, 0.5190645143051721, 0.8665189272051204, 0.8048799639169323, 0.2798374918668536, 0.04718230952565439, 0.42313415663431997, 0.4791128238410486, 0.6502559159425019, 0.8368961788309147, 0.7391938073125803, 0.4406268118943344, 0.9828735524744412, 0.14242812258066673, 0.22624384077108428, 0.6886520018571498, 0.36148143236842145, 0.6289870203671285, 0.9920952774166062, 0.605105253576449, 0.15351318593809504, 0.01258906458383402, 0.1804392858992424, 0.08589081524313136, 0.5972746155310905, 0.621893 ...

# %%
current_run_heads = 0
is_last_flip_heads = False

all_run_heads = []

for i in flips:
    if i >= 0.30:
        if is_last_flip_heads:
            current_run_heads += 1
        
        else:    
            is_last_flip_heads = True
            current_run_heads = 1

    else:
        if current_run_heads != 0:
            all_run_heads.append(current_run_heads)
            
        is_last_flip_heads = False
        current_run_heads = 0
        
print(all_run_heads)
# Out:
# [1, 2, 1, 4, 3, 2, 3, 4, 1, 5, 3, 1, 4, 12, 1, 1, 1, 3, 5, 1, 1, 2, 4, 4, 13, 4, 4, 18, 5, 5, 3, 4, 1, 6, 7, 5, 8, 1, 2, 1, 4, 1, 4, 5, 3, 3, 2, 2, 7, 1, 1, 3, 5, 4, 3, 2, 5, 2, 8, 1, 4, 1, 1, 1, 1, 2, 3, 4, 4, 3, 5, 1, 5, 16, 1, 3, 4, 2, 4, 2, 15, 5, 1, 3, 1, 7, 2, 3, 1, 5, 2, 7, 3, 2, 9, 4, 1, 2, 2, 2]

# %%
# heads runs from 500 flips
plt.hist(all_run_heads)

plt.xlabel('Head Run')
plt.ylabel('Frequency')
plt.title('Heads Runs from 500 Flips')

plt.show()
