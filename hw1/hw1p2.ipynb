# %% [markdown]
# # Problem 2
# Define the random variable N = min {n :
# Pn
# i=1 Xi > 4} as the smallest number of standard
# uniform random samples whose sum exceeds four. Generate a histogram using 100, 1000, and
# 10000 realizations of N. Comment on the expected value E[N].

# %%
import random
import matplotlib.pyplot as plt

# %%
def get_n():
    x = 0
    n = 0
    
    while(x < 4):
        n += 1
        x += random.uniform(0,1)
        # print(x)
    
    return n

# %%
def get_n_x_times(x):
    n_appearances = []
    
    for i in range(x):
        n_appearances.append(get_n())
    
    plt.hist(n_appearances)

# %%
get_n_x_times(100)

# %%
get_n_x_times(1000)

# %%
get_n_x_times(10000)

# %% [markdown]
# E[N] is around 8
